# %%
import pandas as pd

# %%
# Create a series of three different colours and view it

Colours = pd.Series (["Blue", "Red", 'Green'])
Colours
# Out:
# 0     Blue
# 1      Red
# 2    Green
# dtype: object

# %%
# Create a series of three different car types and view it
Cars = pd.Series (["Tesla", "Toyota", "Mercedes"])
Cars
# Out:
# 0       Tesla
# 1      Toyota
# 2    Mercedes
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
Car_data = pd.DataFrame ({"Car": Cars, "Colour": Colours})
Car_data
# Out:
#         Car Colour
# 0     Tesla   Blue
# 1    Toyota    Red
# 2  Mercedes  Green

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame

Car_sales_DataFrame = pd.read_csv ("car_sales_DataFrame.csv")
Car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Export the DataFrame you created to a .csv file

Car_sales_DataFrame.to_csv ("Exported_Car_sales_Dataframe.csv", index = False)

# %%
Car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Find the different datatypes of the car data DataFrame

Car_sales_DataFrame.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()

Car_sales_DataFrame.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()

Car_sales_DataFrame.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
# Create a Series of different numbers and find the mean of them

car_series = pd.Series ((4000, 60000, 8800))

# %%
car_series.mean ()
# Out:
# 24266.666666666668

# %%
# Create a Series of different numbers and find the sum of them

car_series.sum()
# Out:
# 72800

# %%
# List out all the column names of the car sales DataFrame

Car_sales_DataFrame.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame

len(Car_sales_DataFrame)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame

Car_sales_DataFrame.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame

Car_sales_DataFrame.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame

Car_sales_DataFrame.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame

Car_sales_DataFrame.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame

Car_sales_DataFrame.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame

Car_sales_DataFrame["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame

Car_sales_DataFrame["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer

Car_sales_DataFrame["Odometer (KM)"] > 100000
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Odometer (KM), dtype: bool

# %%
# Create a crosstab of the Make and Doors columns

pd.crosstab (Car_sales_DataFrame ["Make"], Car_sales_DataFrame ["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average

Car_sales_DataFrame.groupby (["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Create a histogram of the Odometer column using hist()

Car_sales_DataFrame["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
# Try to plot the Price column using plot()
# To convert the data type for price to integer
# Remove the punctuation from price column

Car_sales_DataFrame ["Price"] = Car_sales_DataFrame ["Price"].str.replace ('[\$\,\.]', '').astype(int)
# Out:
# <ipython-input-28-e26a3ff7dec1>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   Car_sales_DataFrame ["Price"] = Car_sales_DataFrame ["Price"].str.replace ('[\$\,\.]', '').astype(int)

# %%
Car_sales_DataFrame["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
# Remove the punctuation from price column

Car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
Car_sales_DataFrame["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
# Remove the two extra zeros at the end of the price column


Car_sales_DataFrame["Price"] = Car_sales_DataFrame["Price"]/100

# %%
Car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Change the datatype of the Price column to integers

Car_sales_DataFrame["Price"] = Car_sales_DataFrame["Price"].astype(int)
Car_sales_DataFrame["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
# Lower the strings of the Make column

Car_sales_DataFrame["Make"] = Car_sales_DataFrame["Make"].str.lower()
Car_sales_DataFrame["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
# Check out the new DataFrame

Car_sales_missing = pd.read_csv ("car-sales-missing-data.csv")
Car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill the Odometer column missing values with the mean of the column inplace

Car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
Car_sales_missing["Odometer"].fillna (Car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
# View the car sales missing DataFrame and verify the changes

Car_sales_missing["Odometer"] = Car_sales_missing["Odometer"].fillna (Car_sales_missing["Odometer"].mean())
Car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Remove the rest of the missing data inplace

Car_sales_missing.dropna(inplace = True)

# %%
# Verify the missing values are removed by viewing the DataFrame

Car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Create a "Seats" column where every row has a value of 5

Car_sales_missing ["Seats"] = 5
Car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame


Car_sales_missing["Engine size"] = [1.3, 4.5, 2.9, 3.7, 2.1,1.8]
Car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          4.5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          2.9
# 3     BMW  Black   11179.000000    5.0  $22,000      5          3.7
# 4  Nissan  White  213095.000000    4.0   $3,500      5          2.1
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          1.8

# %%
Car_sales_missing ["Price"] = Car_sales_missing ["Price"].str.replace ('[\$\,\.]', '').astype(int)
# Out:
# <ipython-input-44-9841a3d43756>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Car_sales_missing ["Price"] = Car_sales_missing ["Price"].str.replace ('[\$\,\.]', '').astype(int)

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
Car_sales_missing["Price"] = Car_sales_missing["Price"]/100
Car_sales_missing["Price/KM"] = Car_sales_missing ["Price"] / Car_sales_missing["Odometer"]

# %%
Car_sales_missing
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine size  Price/KM
# 0  Toyota  White  150043.000000    4.0   40.0      5          1.3  0.000267
# 1   Honda    Red   87899.000000    4.0   50.0      5          4.5  0.000569
# 2  Toyota   Blue   92302.666667    3.0   70.0      5          2.9  0.000758
# 3     BMW  Black   11179.000000    5.0  220.0      5          3.7  0.019680
# 4  Nissan  White  213095.000000    4.0   35.0      5          2.1  0.000164
# 5  Toyota  Green   92302.666667    4.0   45.0      5          1.8  0.000488

# %%
# Remove the last column you added using .drop()

Car_sales_missing_dropped = Car_sales_missing.drop("Price/KM", axis = 1)

# %%
Car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine size
# 0  Toyota  White  150043.000000    4.0   40.0      5          1.3
# 1   Honda    Red   87899.000000    4.0   50.0      5          4.5
# 2  Toyota   Blue   92302.666667    3.0   70.0      5          2.9
# 3     BMW  Black   11179.000000    5.0  220.0      5          3.7
# 4  Nissan  White  213095.000000    4.0   35.0      5          2.1
# 5  Toyota  Green   92302.666667    4.0   45.0      5          1.8

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable

Car_sales_missing_dropped.sample(frac=1)
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine size
# 4  Nissan  White  213095.000000    4.0   35.0      5          2.1
# 1   Honda    Red   87899.000000    4.0   50.0      5          4.5
# 5  Toyota  Green   92302.666667    4.0   45.0      5          1.8
# 0  Toyota  White  150043.000000    4.0   40.0      5          1.3
# 2  Toyota   Blue   92302.666667    3.0   70.0      5          2.9
# 3     BMW  Black   11179.000000    5.0  220.0      5          3.7

# %%
# Reset the indexes of the shuffled DataFrame

Car_sales_missing_dropped.reset_index(drop = True)
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine size
# 0  Toyota  White  150043.000000    4.0   40.0      5          1.3
# 1   Honda    Red   87899.000000    4.0   50.0      5          4.5
# 2  Toyota   Blue   92302.666667    3.0   70.0      5          2.9
# 3     BMW  Black   11179.000000    5.0  220.0      5          3.7
# 4  Nissan  White  213095.000000    4.0   35.0      5          2.1
# 5  Toyota  Green   92302.666667    4.0   45.0      5          1.8

# %%
# Convert odometer to Kilometer

Car_sales_missing["Odometer"] = Car_sales_missing["Odometer"]*100

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame

Car_sales_missing["Odometer"] = Car_sales_missing ["Odometer"].apply(lambda x: x/1.6)

# %%
Car_sales_missing
# Out:
#      Make Colour      Odometer  Doors  Price  Seats  Engine size  Price/KM
# 0  Toyota  White  9.377688e+06    4.0   40.0      5          1.3  0.000267
# 1   Honda    Red  5.493688e+06    4.0   50.0      5          4.5  0.000569
# 2  Toyota   Blue  5.768917e+06    3.0   70.0      5          2.9  0.000758
# 3     BMW  Black  6.986875e+05    5.0  220.0      5          3.7  0.019680
# 4  Nissan  White  1.331844e+07    4.0   35.0      5          2.1  0.000164
# 5  Toyota  Green  5.768917e+06    4.0   45.0      5          1.8  0.000488
